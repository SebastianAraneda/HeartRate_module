# %%
import os
import glob
import pandas as pd
import re
import numpy as np
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

path = './metrics_datasets/'
extension = 'csv'
os.chdir(path)
predictions_dataset = glob.glob('*.{}'.format(extension))
predictions_dataset.sort()

# %% [markdown]
# ## Diccionatio de Dataframes:
# * dataframes[Video][Método]
# * dataframe[Video]['comparative'][Método]
#
# - Video: nombre del video. Los nombres están almacenados en la variable "videos"
# - Método: nombre del método rPPG utilizado en el video. ['cupyCHROM','cupyPOS','extraction_GT','torchCHROM']
# - 'comparativa': muestra un diccionario de dataframes ['cupyCHROM','cupyPOS','torchCHROM'] unidos al dataframe 'extraction_GT'

# %%
df_by_name = {}
df_by_method = {}
df_by_activity = {}

mae_by_name = {}
mae_by_method = {}
mae_by_method_act = {}
all_gtruth = {}
all_predicted = {}
all_gtruth_act = {}
all_predicted_act = {}
global_mae_by_method = {}

videos = []

# get main dataframe
for file in predictions_dataset:
    str = re.split('\(|\)', file)
    name_and_action = str[0]
    method = str[1]

    if name_and_action not in df_by_name:
        videos.append(name_and_action)
        methodes = {}

    methodes[method] = pd.read_csv(file)
    df_by_name[name_and_action] = methodes

# get dataframe with ground trueth comparatives by name
for name in df_by_name:
    comparatives = {}
    df_by_name[name]['comparatives'] = comparatives
    
    for method in df_by_name[name]:
        if method == 'extraction_GT' or method == 'comparatives':
            continue

        pred = df_by_name[name][method].set_index('time')
        gt = df_by_name[name]['extraction_GT'].set_index('time gt')   ## error??

        comparatives[method]= gt.join(pred)

# get dictionary with MAE by name
for video in videos:
    df_dict = df_by_name[video]['comparatives']
    methodes = list(df_dict.keys())
    mae_for_method = {}
    for method in methodes:
        df = df_dict[method]    
        gtruth = df.dropna()['BPM gt'].to_numpy()
        predicted = df.dropna()['BPM predicted'].to_numpy()
        mae_for_method[method] = mean_absolute_error(gtruth, predicted)
    
    mae_by_name[video] = mae_for_method

# get global dictionary with MAE by method

for video in videos:
    df = df_by_name[video]['comparatives']
    methodes_in_video = list(df_dict.keys())
    for method in methodes_in_video:
        
        if method not in mae_by_method:
            mae_by_method[method] = {video : {}}
            all_gtruth[method] = []
            all_predicted[method] = []
            global_mae_by_method[method] = []
            
        gtruth = df[method].dropna()['BPM gt'].to_numpy()
        predicted = df[method].dropna()['BPM predicted'].to_numpy()
        for data_i in range(len(gtruth)):
            all_gtruth[method].append(gtruth[data_i])
            all_predicted[method].append(predicted[data_i])
        
        mae = mean_absolute_error(gtruth, predicted)
        mae_by_method[method][video] = mae
        
for method in global_mae_by_method:
    mae_global = mean_absolute_error(all_gtruth[method], all_predicted[method])
    global_mae_by_method[method] = mae_global


#get global MAE for all videos, by activity
for video in videos:
    df = df_by_name[video]['comparatives']
    methodes_in_video = list(df_dict.keys())
    act = video.split('_')[1]
    for method in methodes_in_video:

        if method not in mae_by_method_act:
            mae_by_method_act[method] =  {}

        if act not in mae_by_method_act[method]:
            mae_by_method_act[method][act] = 0

        if method not in all_gtruth_act:
            all_gtruth_act[method] = {}
            all_predicted_act[method] = {}

        if act not in all_gtruth_act[method]:
            all_gtruth_act[method][act] = []
            all_predicted_act[method][act] = []
        
        gtruth = df[method].dropna()['BPM gt'].to_numpy()
        predicted = df[method].dropna()['BPM predicted'].to_numpy()
        for data_i in range(len(gtruth)):
            all_gtruth_act[method][act].append(gtruth[data_i])
            all_predicted_act[method][act].append(predicted[data_i])

#print(all_gtruth_act.keys())
#print(all_gtruth_act['cupyCHROM'].keys())
#print(all_gtruth_act['cupyPOS'].keys())
#print(all_gtruth_act['torchCHROM'].keys())


for method in mae_by_method_act:
    for act in mae_by_method_act[method]:
        mae_global = mean_absolute_error(all_gtruth_act[method][act], all_predicted_act[method][act])
        mae_by_method_act[method][act] = mae_global

# %%
df_by_name = {}
df_by_method = {}
df_by_activity = {}

mae_by_name = {}
mae_by_method = {}
mae_by_method_act = {}
all_gtruth = {}
all_predicted = {}
all_gtruth_act = {}
all_predicted_act = {}
global_mae_by_method = {}

videos = []

# get main dataframe
for file in predictions_dataset:
    str = re.split('\(|\)', file)
    name_and_action = str[0]
    method = str[1]

    if name_and_action not in df_by_name:
        videos.append(name_and_action)
        df_by_name[name_and_action] = {}
        methodes ={}

    print(name_and_action,method)
    #df_by_name[name_and_action] = {method: pd.read_csv(file)}

    methodes[method] = pd.read_csv(file)
    df_by_name[name_and_action] = methodes
# Out:
# alex_gym cupyCHROM
# alex_gym cupyPOS
# alex_gym extraction_GT
# alex_gym torchCHROM
# alex_resting cupyCHROM
# alex_resting cupyPOS
# alex_resting extraction_GT
# alex_resting torchCHROM
# alex_rotation cupyCHROM
# alex_rotation cupyPOS
# alex_rotation extraction_GT
# alex_rotation torchCHROM
# alex_talk cupyCHROM
# alex_talk cupyPOS
# alex_talk extraction_GT
# alex_talk torchCHROM
# angelo_resting cupyCHROM
# angelo_resting cupyPOS
# angelo_resting extraction_GT
# angelo_resting torchCHROM
# angelo_rotation cupyCHROM
# angelo_rotation cupyPOS
# angelo_rotation extraction_GT
# angelo_rotation torchCHROM
# angelo_talk cupyCHROM
# angelo_talk cupyPOS
# angelo_talk extraction_GT
# angelo_talk torchCHROM
# cpi_gym cupyCHROM
# cpi_gym cupyPOS
# cpi_gym extraction_GT
# cpi_gym torchCHROM
# cpi_resting cupyCHROM
# cpi_resting cupyPOS
# cpi_resting extraction_GT
# cpi_resting torchCHROM
# cpi_rotation cupyCHROM
# cpi_rotation cupyPOS
# cpi_rotation extraction_GT
# cpi_rotation torchCHROM
# cpi_talk cupyCHROM
# cpi_talk cupyPOS
# cpi_talk extraction_GT
# cpi_talk torchCHROM
# david_gym cupyCHROM
# david_gym cupyPOS
# david_gym extraction_GT
# david_gym torchCHROM
# david_resting cupyCHROM
# david_resting cupyPOS
# david_resting extraction_GT
# david_resting torchCHROM
# david_rotation cupyCHROM
# david_rotation cupyPOS
# david_rotation extraction_GT
# david_rotation torchCHROM
# david_talk cupyCHROM
# david_talk cupyPOS
# david_talk extraction_GT
# david_talk torchCHROM
# felix_resting cupyCHROM
# felix_resting cupyPOS
# felix_resting extraction_GT
# felix_resting torchCHROM
# felix_rotation cupyCHROM
# felix_rotation cupyPOS
# felix_rotation extraction_GT
# felix_rotation torchCHROM
# felix_talk cupyCHROM
# felix_talk cupyPOS
# felix_talk extraction_GT
# felix_talk torchCHROM
# harun_gym cupyCHROM
# harun_gym cupyPOS
# harun_gym extraction_GT
# harun_gym torchCHROM
# harun_resting cupyCHROM
# harun_resting cupyPOS
# harun_resting extraction_GT
# harun_resting torchCHROM
# harun_rotation cupyCHROM
# harun_rotation cupyPOS
# harun_rotation extraction_GT
# harun_rotation torchCHROM
# harun_talk cupyCHROM
# harun_talk cupyPOS
# harun_talk extraction_GT
# harun_talk torchCHROM

# %%
l = list(predictions_dataset).sort()

# %%
for file in predictions_dataset:
    print(file)
# Out:
# alex_gym(cupyCHROM).csv
# alex_gym(cupyPOS).csv
# alex_gym(extraction_GT).csv
# alex_gym(torchCHROM).csv
# alex_resting(cupyCHROM).csv
# alex_resting(cupyPOS).csv
# alex_resting(extraction_GT).csv
# alex_resting(torchCHROM).csv
# alex_rotation(cupyCHROM).csv
# alex_rotation(cupyPOS).csv
# alex_rotation(extraction_GT).csv
# alex_rotation(torchCHROM).csv
# alex_talk(cupyCHROM).csv
# alex_talk(cupyPOS).csv
# alex_talk(extraction_GT).csv
# alex_talk(torchCHROM).csv
# angelo_resting(cupyCHROM).csv
# angelo_resting(cupyPOS).csv
# angelo_resting(extraction_GT).csv
# angelo_resting(torchCHROM).csv
# angelo_rotation(cupyCHROM).csv
# angelo_rotation(cupyPOS).csv
# angelo_rotation(extraction_GT).csv
# angelo_rotation(torchCHROM).csv
# angelo_talk(cupyCHROM).csv
# angelo_talk(cupyPOS).csv
# angelo_talk(extraction_GT).csv
# angelo_talk(torchCHROM).csv
# cpi_gym(cupyCHROM).csv
# cpi_gym(cupyPOS).csv
# cpi_gym(extraction_GT).csv
# cpi_gym(torchCHROM).csv
# cpi_resting(cupyCHROM).csv
# cpi_resting(cupyPOS).csv
# cpi_resting(extraction_GT).csv
# cpi_resting(torchCHROM).csv
# cpi_rotation(cupyCHROM).csv
# cpi_rotation(cupyPOS).csv
# cpi_rotation(extraction_GT).csv
# cpi_rotation(torchCHROM).csv
# cpi_talk(cupyCHROM).csv
# cpi_talk(cupyPOS).csv
# cpi_talk(extraction_GT).csv
# cpi_talk(torchCHROM).csv
# david_gym(cupyCHROM).csv
# david_gym(cupyPOS).csv
# david_gym(extraction_GT).csv
# david_gym(torchCHROM).csv
# david_resting(cupyCHROM).csv
# david_resting(cupyPOS).csv
# david_resting(extraction_GT).csv
# david_resting(torchCHROM).csv
# david_rotation(cupyCHROM).csv
# david_rotation(cupyPOS).csv
# david_rotation(extraction_GT).csv
# david_rotation(torchCHROM).csv
# david_talk(cupyCHROM).csv
# david_talk(cupyPOS).csv
# david_talk(extraction_GT).csv
# david_talk(torchCHROM).csv
# felix_resting(cupyCHROM).csv
# felix_resting(cupyPOS).csv
# felix_resting(extraction_GT).csv
# felix_resting(torchCHROM).csv
# felix_rotation(cupyCHROM).csv
# felix_rotation(cupyPOS).csv
# felix_rotation(extraction_GT).csv
# felix_rotation(torchCHROM).csv
# felix_talk(cupyCHROM).csv
# felix_talk(cupyPOS).csv
# felix_talk(extraction_GT).csv
# felix_talk(torchCHROM).csv
# harun_gym(cupyCHROM).csv
# harun_gym(cupyPOS).csv
# harun_gym(extraction_GT).csv
# harun_gym(torchCHROM).csv
# harun_resting(cupyCHROM).csv
# harun_resting(cupyPOS).csv
# harun_resting(extraction_GT).csv
# harun_resting(torchCHROM).csv
# harun_rotation(cupyCHROM).csv
# harun_rotation(cupyPOS).csv
# harun_rotation(extraction_GT).csv
# harun_rotation(torchCHROM).csv
# harun_talk(cupyCHROM).csv
# harun_talk(cupyPOS).csv
# harun_talk(extraction_GT).csv
# harun_talk(torchCHROM).csv

# %%
'alex_gym' in df_by_name
# Out:
# True

# %%
df_by_name['harun_talk'].keys()
# Out:
# dict_keys(['cupyPOS'])

# %%
df_by_name['alex_resting']['cupyCHROM']
# Out:
#       time  BPM predicted  uncert rPPG method
# 0      3.0      90.087891     0.0  cupy_CHROM
# 1      4.0      95.214844     0.0  cupy_CHROM
# 2      5.0      98.144531     0.0  cupy_CHROM
# 3      6.0     101.074219     0.0  cupy_CHROM
# 4      7.0     101.074219     0.0  cupy_CHROM
# ..     ...            ...     ...         ...
# 220  223.0      91.552734     0.0  cupy_CHROM
# 221  224.0      90.820312     0.0  cupy_CHROM
# 222  225.0      92.285156     0.0  cupy_CHROM
# 223  226.0      93.017578     0.0  cupy_CHROM
# 224  227.0      92.285156     0.0  cupy_CHROM
#
# [225 rows x 4 columns]

# %%
df_by_name['alex_gym']['cupyCHROM']
# Out:
#       time  BPM predicted  uncert rPPG method
# 0      3.0      90.087891     0.0  cupy_CHROM
# 1      4.0      95.214844     0.0  cupy_CHROM
# 2      5.0      98.144531     0.0  cupy_CHROM
# 3      6.0     101.074219     0.0  cupy_CHROM
# 4      7.0     101.074219     0.0  cupy_CHROM
# ..     ...            ...     ...         ...
# 220  223.0      91.552734     0.0  cupy_CHROM
# 221  224.0      90.820312     0.0  cupy_CHROM
# 222  225.0      92.285156     0.0  cupy_CHROM
# 223  226.0      93.017578     0.0  cupy_CHROM
# 224  227.0      92.285156     0.0  cupy_CHROM
#
# [225 rows x 4 columns]

# %%
df_by_name['alex_rotation']['cupyCHROM']
# Out:
#       time  BPM predicted  uncert rPPG method
# 0      3.0      90.087891     0.0  cupy_CHROM
# 1      4.0      95.214844     0.0  cupy_CHROM
# 2      5.0      98.144531     0.0  cupy_CHROM
# 3      6.0     101.074219     0.0  cupy_CHROM
# 4      7.0     101.074219     0.0  cupy_CHROM
# ..     ...            ...     ...         ...
# 220  223.0      91.552734     0.0  cupy_CHROM
# 221  224.0      90.820312     0.0  cupy_CHROM
# 222  225.0      92.285156     0.0  cupy_CHROM
# 223  226.0      93.017578     0.0  cupy_CHROM
# 224  227.0      92.285156     0.0  cupy_CHROM
#
# [225 rows x 4 columns]

# %%
i=800
print(all_predicted_act['cupyCHROM']['rotation'][i])
print(all_predicted_act['cupyCHROM']['gym'][i])
# Out:
# 132.568359375
# 132.568359375

# %%
def plot_mae(mae_list): ## mae_list: dictionary with methodes and mae for ONE video
    k = list(mae_list.keys())
    v = []
    for key in mae_list:
        v.append(mae_list[key])
    
    plt.plot(k,v)
    plt.show()

def plot_all_maes(mae_by_name): ## mae_list: dictionary with methodes and mae for ALL video
    for video in mae_by_name:
        k = list(mae_by_name[video].keys())
        v = []
        for method in k:
            v.append(mae_by_name[video][method])
        plt.plot(k,v, label=video)
    plt.legend(loc='upper right')
    plt.show()
    

def plot_by_activity(mae_by_name, methodes_list = ['cupyCHROM', 'cupyPOS', 'torchCHROM']):
    ## x: actividad
    ## y: MAE
    ## color de línea por cada individuo
    videos = list(mae_by_name.keys()) 
    mae_by_act = {}
    methodes_by_video = {}
    for video in videos:
        temp = video.split('_')
        name, act = temp
        if act not in mae_by_act:
            mae_by_act[act] = []   
        mae_by_act[act].append(video)
        methodes_by_video[video] = list(mae_by_name[video].keys()) ## para iterar por cada método de video

    for met in methodes_list:
        for act in mae_by_act:
            #x = list(mae_by_act.keys())
            y = []                
            x = []
                
            for video in range(len(mae_by_act[act])):
                if met in methodes_by_video[mae_by_act[act][video]]:
                    y.append(mae_by_name[mae_by_act[act][video]][met])
                    x.append(act)
                plt.scatter(x, y)
                    
        plt.title(met)
        plt.show()

def subplot_by_activity(mae_by_name, 
    activity_list = ['gym', 'resting', 'rotation', 'talk'], 
    methodes_list = ['cupyCHROM', 'cupyPOS', 'torchCHROM']):
    if len(methodes_list) <= 1:
        print("methodes list must have at least two elements...")
        return 0
    ## x: actividad
    ## y: MAE
    ## color por cada individuo
    videos = list(mae_by_name.keys()) 

    fig, axs = plt.subplots(1, len(methodes_list), figsize=(15, 5))

    for met in methodes_list:
        for act in activity_list:
            for video in videos:
                temp = video.split('_')
                v_name, v_act = temp
                if v_act == act:
                    x = act
                    y = mae_by_name[video][met]
                    axs[methodes_list.index(met)].scatter(x,y)
                    axs[methodes_list.index(met)].title.set_text(met)

    plt.show()

#def subplot_method_act_vs_globalmae:

def plot_global_mae(global_mae):
    method_color = {
        'cupyCHROM': 'o:r', 
        'cupyPOS': 'o:g', 
        'torchCHROM': 'o:b'
        }
    for method in mae_by_method_act:
        x = []
        y = []
        for act in mae_by_method_act[method]:
            mae_by_method_act[method][act]
            x.append(act)
            y.append(mae_by_method_act[method][act])
        plt.plot(x,y ,method_color[method], label=method)
    plt.grid()
    plt.legend()
    plt.show()

# %%
plot_global_mae(mae_by_method_act)

# %%
mae_by_method_act
# Out:
# {'cupyCHROM': {'gym': 22.279012926706827,
#   'resting': 2.0278497409326426,
#   'rotation': 4.611313215648855,
#   'talk': 12.044157045077434},
#  'cupyPOS': {'gym': 12.518855107931726,
#   'resting': 2.457279185556995,
#   'rotation': 4.887071604643766,
#   'talk': 10.65839325221239},
#  'torchCHROM': {'gym': 22.279012926706827,
#   'resting': 2.0278497409326426,
#   'rotation': 4.611313215648855,
#   'talk': 12.044157045077434}}

# %%
subplot_by_activity(mae_by_name)

# %% [markdown]
# |modelo|actividad|mae global|
# |cupyPOS|gym|33|
# |cupyPOS|rest|33|
# |cupyPOS|rotation|33|
# |cupyPOS|talk|33|
# |torchCHROM|gym|33|
# |torchCHROM|rest|33|
# |torchCHROM|rotation|33|
# |torchCHROM|talk|33|
